# %% [markdown]
# # Nesse curso:
# ![image.png](attachment:image.png)

# %% [markdown]
# # Formatação (usando o .format)

# %%
print('meu nome é {} e meu apelido é {}'.format('Lucas', 'Lucão'))
print('meu nome é {one} e meu apelido é {two}... O {one}'.format(one='Lucas', two='Lucão'))
# Out:
# meu nome é Lucas e meu apelido é Lucão
# meu nome é Lucas e meu apelido é Lucão... O Lucas

# %% [markdown]
# # Slice

# %%
s = 'Corinthians'

# %%
s[:6]
# Out:
# 'Corint'

# %%
s[0:]
# Out:
# 'Corinthians'

# %%
s[0:-2]
# Out:
# 'Corinthia'

# %% [markdown]
# * Manipulando vetor

# %%
lista = ['a', 'b', 'c']
lista.append('d')
lista[1] = 'Index'

# %%
lista[1:]
# Out:
# ['Index', 'c', 'd']

# %% [markdown]
# * Nested list

# %%
nest = [1, 2, 3, [4, 5,['point']]]

# %%
nest [3]
# Out:
# [4, 5, ['point']]

# %%
nest[3][2][0]
# Out:
# 'point'

# %% [markdown]
# --------------------------------------------------------
# # Dicionarios

# %% [markdown]
# * KVs

# %%
d = {'key1':'value', 'key2':[2, 3]}

# %%
d['key2']
# Out:
# [2, 3]

# %%
list = d['key2']
list[1]
# Out:
# 3

# %%
d = {'k1': {'inner': [1, 2, 3]}}

# %%
d['k1']['inner'][1]
# Out:
# 2

# %% [markdown]
# * Tuplas
#
#   * Elas não são mutáveis; Similar às const

# %%
t = (1, 2, 3)
t
# Out:
# (1, 2, 3)

# %%
t[1] = 'ola' # Terá um erro

# %% [markdown]
# * Coleções (set)
#   * Itens são unicos, não se repetindo

# %%
{1, 2, 3}
# Out:
# {1, 2, 3}

# %%
{1, 1, 1, 1, 1, 1, 2, 3, 3} #É reduzido para unicos elementos
# Out:
# {1, 2, 3}

# %% [markdown]
# * Podemos transformar um array em uma coleção usando o método `SET()`

# %%
s = set([1, 1, 1, 2, 2, 3])
s
# Out:
# {1, 2, 3}

# %%
s.add(5)
s.add(4)
